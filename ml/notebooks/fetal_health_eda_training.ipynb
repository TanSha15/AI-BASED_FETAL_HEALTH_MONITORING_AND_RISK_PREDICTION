# %% [markdown]
# # Fetal Health Classification & Risk Prediction
# Exploratory Data Analysis (EDA) and Gradient Boosting Model Training on the Kaggle Cardiotocography (CTG) Dataset.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import classification_report, confusion_matrix
import joblib

# Load model
model_dict = joblib.load('../models/fetal_health_model.pkl')
print('Model loaded successfully:', model_dict['model'])
print('Features:', len(model_dict['feature_names']))
